# %%
import nibabel as nib
import numpy as np
import os
import matplotlib.pyplot as plt
from nilearn.plotting import plot_stat_map, plot_anat, plot_img
from pathlib import Path
from ipywidgets import IntSlider, interact
import pywt
import fwt97_2d

# %%
def plot_img(img, cmap = 'gray'):
    plt.figure(figsize=(12,8))
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.show()

# %%
# #делаем из сырых срезов мрт 3d картинку 
# import dicom2nifti
# dicom2nifti.dicom_series_to_nifti('fcd_brains', 'fcd_00.nii.gz', reorient_nifti=True)

# %%
# скачиваем себе эту 3d картинку
brain = nib.load('10_2.nii.gz')

# %%
plot_anat(brain)

# %%
brain = brain.get_fdata()

# %%
brain.shape
# Out:
# (448, 448, 256)

# %%
sld_sagital = IntSlider(min=0, max=brain.shape[0], step=1, continuous_update=True)
sld_coronal = IntSlider(min=0, max=brain.shape[1], step=1, continuous_update=True)
sld_axial   = IntSlider(min=0, max=brain.shape[2], step=1, continuous_update=True)

# %%
def vary_coordinate(coordinate_sagital, coordinate_coronal, coordinate_axial, axis = None):
    if axis == None:
        pass
    if axis == 'sagital':
        plot_img(brain[coordinate_sagital,:,:])
    if axis == 'coronal':
        plot_img(brain[:,coordinate_coronal ,:])
    if axis == 'axial':
        plot_img(brain[:,:, coordinate_axial])

# %%
interact(vary_coordinate, 
         coordinate_axial = sld_axial,
         coordinate_sagital = sld_sagital,
         coordinate_coronal = sld_coronal,
         axis = 'axial')
# Out:
# interactive(children=(IntSlider(value=0, description='coordinate_sagital', max=448), IntSlider(value=0, descri…
# <function __main__.vary_coordinate(coordinate_sagital, coordinate_coronal, coordinate_axial, axis=None)>

# %%
A1 = brain[55:395,:380,160].T

# %%
print(f'mean = {A1.mean()}')
print(f'variance = {A1.var()}')
# Out:
# mean = 162.2202321981424
# variance = 19478.45326248478

# %%
#A2 = (A1 - A1.mean())/A1.std()
A2 = (A1 - A1.min())/(A1.max() - A1.min())

# %%
print(f'mean = {A2.mean()}')
print(f'variance = {A2.var()}')
# Out:
# mean = 0.1818612468589041
# variance = 0.02448075225532987

# %%
plt.imshow(A2, cmap='gray');

# %%
import cv2

# %%
A1 = cv2.resize(A1, (256,256))

# %%
A2 = cv2.resize(A2, (256,256))

# %%
plt.imshow(A2, interpolation='nearest', cmap='gray');

# %% [markdown]
# ### $9/7$ tap Daubeshie wavelet transform

# %%
coeffs1  = fwt97_2d.fwt97_2d(A1.copy(), 1)
LL1 = coeffs1[:128,:128]
plt.figure(dpi=150)
plt.imshow(coeffs1[:128,:128], interpolation="nearest", cmap=plt.cm.gray);

# %%
titles = ['LL1', 'LH1', 'HL1', 'HH1']

coeffs2  = fwt97_2d.fwt97_2d(A2.copy(), 1)
LL2 = coeffs2[:128,:128]
plt.figure(dpi=150)
plt.imshow(coeffs2[:128,:128], interpolation="nearest", cmap=plt.cm.gray);

# %%
# titles = ['LL1', 'LH1', 'HL1', 'HH1']

# w = pywt.Wavelet('db1')
# coeffs = pywt.dwt2(A1, w)

# LL1, (LH1, HL1, HH1) = coeffs

# fig = plt.figure(figsize=(12, 3))
# for i, a in enumerate([LL1, LH1, HL1, HH1]):
#     ax = fig.add_subplot(1, 4, i + 1)
#     ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
#     ax.set_title(titles[i], fontsize=10)
#     ax.set_xticks([])
#     ax.set_yticks([])

# fig.tight_layout()
# plt.show()

# %%
# titles = ['LL2', 'LH2', 'HL2', 'HH2']

# w = pywt.Wavelet('db1')
# coeffs = pywt.dwt2(A2, w)

# LL2, (LH2, HL2, HH2) = coeffs

# fig = plt.figure(figsize=(12, 3))
# for i, a in enumerate([LL2, LH2, HL2, HH2]):
#     ax = fig.add_subplot(1, 4, i + 1)
#     ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
#     ax.set_title(titles[i], fontsize=10)
#     ax.set_xticks([])
#     ax.set_yticks([])

# fig.tight_layout()
# plt.show()

# %% [markdown]
# ## SVD of LL's

# %%
U1, S1, V1 = np.linalg.svd(LL1, full_matrices = False)
U2, S2, V2 = np.linalg.svd(LL2, full_matrices = False)

# %% [markdown]
# ## Different methods of finding $\xi$

# %%
xi_1 = S2[0]/S1[0]

# %%
xi_2 = U2.max()/U1.max()

# %%
xi_3 = (U2.max() + V2.max())/(U1.max() + V1.max())

# %% [markdown]
# ## New $\Sigma$

# %%
def new_sigma1(sigma2, xi):
    return xi*sigma2

# %%
def new_sigma2(sigma1, sigma2, xi):
    return 0.5*(xi*sigma1+sigma2/xi)

# %%
def new_sigma3(sigma1, sigma2, xi, mu):
    return mu*xi*sigma1 + (1-mu)*sigma2/xi

# %% [markdown]
# ## New LL

# %%
def new_LL(new_sigma):
    new_sigma = np.diag(new_sigma)
    return U2 @ new_sigma @ V2

# %% [markdown]
# ## Experiments with different approaches

# %%
coeffs = coeffs2.copy()

# %%
# Article of 2014
new_S = new_sigma1(S2, xi_2)
LL = new_LL(new_S)
coeffs[:128,:128] = LL
brain1 = fwt97_2d.iwt97_2d(coeffs)
#brain1 = pywt.idwt2((LL, (LH2, HL2, HH2)), w)

titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 8))
for i, a in enumerate([A2, brain1]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=14)
    ax.set_xticks([])
    ax.set_yticks([])
fig.tight_layout()
plt.show()

# %%
titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 5))
for i, a in enumerate([A2, brain1]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.hist(a.reshape(-1), bins = 1000)
    ax.set_title(titles[i], fontsize=14)
fig.tight_layout()
plt.show()

# %%
coeffs = coeffs2.copy()

# %%
# Article of 2015
new_S = new_sigma2(S1, S2, xi_3)
LL = new_LL(new_S)
coeffs[:128,:128] = LL
brain2 = fwt97_2d.iwt97_2d(coeffs)
#brain2 = pywt.idwt2((LL, (LH2, HL2, HH2)), w)

titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 8))
for i, a in enumerate([A2, brain2]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=14)
    ax.set_xticks([])
    ax.set_yticks([])
fig.tight_layout()
plt.show()

# %%
titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 5))
for i, a in enumerate([A2, brain2]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.hist(a.reshape(-1), bins = 1000)
    ax.set_title(titles[i], fontsize=14)
fig.tight_layout()
plt.show()

# %%
coeffs = coeffs2.copy()

# %%
# Main article
coeffs[:128,:128] = LL
brain3 = fwt97_2d.iwt97_2d(coeffs)
mu = 0.1
new_S = new_sigma3(S1, S2, xi_3, mu)
LL = new_LL(new_S)

#brain3 = pywt.idwt2((LL, (LH2, HL2, HH2)), w)

titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 8))
for i, a in enumerate([A2, brain3]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=14)
    ax.set_xticks([])
    ax.set_yticks([])
fig.tight_layout()
plt.show()

# %%
titles = ['Original', 'New']
fig = plt.figure(figsize=(16, 5))
for i, a in enumerate([A2, brain3]):
    ax = fig.add_subplot(1, 2, i + 1)
    ax.hist(a.reshape(-1), bins = 1000)
    ax.set_title(titles[i], fontsize=14)
fig.tight_layout()
plt.show()
